# %%
import pandas as pd

# %% [markdown]
# #### 1. python library 함수를 사용하여 엑셀 파일을 불러오고, DataFrame을 출력해주세요

# %%
df = pd.read_excel('/Users/jinee/Downloads/관서별 5대범죄 발생 및 검거.xlsx') #excel file 불러오는 함수
df
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0      계  126401   82680     163     156     276     257    5449    5069
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# ...

# %% [markdown]
# #### 2. 각 경찰서(관서명)를 해당 구 이름으로 매핑하여 '구별'이라는 새로운 column을 형성하고, Dataframe을 출력해주세요.
#  - 매칭되지 않는 경찰서명에 대해서는 기본값 '구 없음'을 할당합니다.

# %% [markdown]
# [참고자료]
# '서대문서': '서대문구', '수서서': '강남구', '강서서': '강서구', '서초서': '서초구',
# '서부서': '은평구', '중부서': '중구', '종로서': '종로구', '남대문서': '중구',
# '혜화서': '종로구', '용산서': '용산구', '성북서': '성북구', '동대문서': '동대문구',
# '마포서': '마포구', '영등포서': '영등포구', '성동서': '성동구', '동작서': '동작구',
# '광진서': '광진구', '강북서': '강북구', '금천서': '금천구', '중랑서': '중랑구',
# '강남서': '강남구', '관악서': '관악구', '강동서': '강동구', '종암서': '성북구',
# '구로서': '구로구', '양천서': '양천구', '송파서': '송파구', '노원서': '노원구',
# '방배서': '서초구', '은평서': '은평구', '도봉서': '도봉구'

# %%
#매핑 자료 딕셔너리를 우선 만들어 준다.
mapping = {
'서대문서': '서대문구', '수서서': '강남구', '강서서': '강서구', '서초서': '서초구',
'서부서': '은평구', '중부서': '중구', '종로서': '종로구', '남대문서': '중구',
'혜화서': '종로구', '용산서': '용산구', '성북서': '성북구', '동대문서': '동대문구',
'마포서': '마포구', '영등포서': '영등포구', '성동서': '성동구', '동작서': '동작구',
'광진서': '광진구', '강북서': '강북구', '금천서': '금천구', '중랑서': '중랑구',
'강남서': '강남구', '관악서': '관악구', '강동서': '강동구', '종암서': '성북구', 
'구로서': '구로구', '양천서': '양천구', '송파서': '송파구', '노원서': '노원구', 
'방배서': '서초구', '은평서': '은평구', '도봉서': '도봉구'
}

# %%
# 관서명을 구별로 매핑해서 새로운 컬럼 만든다.
df['구별'] = df['관서명'].map(mapping).fillna('구 없음') #fillna() 함수로 결측값을 '구 없음'으로 대체
df

# %% [markdown]
# #### 3. pivot_table 을 사용하여 관서별 데이터를 구별 데이터로 변경하고,
# #### 같은 구의 경우에는 sum을 적용하여 더해주세요. (index : 관서 이름 -> 구 이름)

# %%
table = pd.pivot_table(
    df,
    index ='구별',
    aggfunc ='sum'
) #index와 aggfunc 
table

# %% [markdown]
# #### 4. 구 없음 행은 drop을 활용하여 삭제해주세요.

# %% [markdown]
# [참고]
# 데이터프레임명.drop([row])

# %%
table = table.drop(['구 없음']) #drop의 기본값은 axis=0으로 행을 삭제하기 때문에 axis=0를 안넣었지만, 열을 삭제하려는 경우 axis=1을 지정해줘야한다. 
table

# %% [markdown]
# #### 5. 각 범죄 별로 검거율을 계산하고, 각 검거율 데이터 column을 DataFrame에 추가해주세요.

# %% [markdown]
# [추가해야할 column]
# 강간검거율,
# 강도검거율,
# 살인검거율,
# 절도검거율,
# 폭력검거율,
# 검거율

# %% [markdown]
# ##### 검거율 계산법 1 : 열이 5개 밖에 안되니까 노가다로 해주기

# %%
# 검거율 계산법 : 검거율 = 검거/발생 * 100
table['강간검거율'] = (table['강간(검거)'] / table['강간(발생)']) * 100
table['강도검거율'] = (table['강도(검거)'] / table['강도(발생)']) * 100
table['살인검거율'] = (table['살인(검거)'] / table['살인(발생)']) * 100
table['절도검거율'] = (table['절도(검거)'] / table['절도(발생)']) * 100
table['폭력검거율'] = (table['폭력(검거)'] / table['폭력(발생)']) * 100

# %% [markdown]
# ##### 검거율 계산법 2: for loop 쓰기

# %%
#검거 유형 리스트로 만들기
crime_type = ['강간', '강도', '살인', '절도', '폭력']

for crime in crime_type:
    table[f'{crime}검거율'] = (table[f'{crime}(검거)'] / table[f'{crime}(발생)']) * 100
table
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)  살인(검거)  살인(발생)  소계(검거)  소계(발생)  절도(검거)  \
# 구별
# 강남구      349     449      18      21      10      13    5732    8617    1650
# 강동구      123     156       8       6       3       4    3171    5244     789
# 강북구      126     153      13      14       8       7    3113    4257     618
# 강서구      191     262      13      13       8       7    4190    5585    1260
# 관악구      221     320      14      12       8       9    3712    6345     827
# 광진구      220     240      26      14       4       4    3707    5909    1277
# 구로구      164     281      11      15       6       8    3502    5646     889
# 금천구      122     151       6       6       4       3    2796    3781     888
# 노원구      121     197       7       7      10      10    3268    5130     801
# 도봉구      106     102      10       9       3       3    1900    2664     478
# 동대문구     146     173      13      13       5       5    3205    4720     814
# ...

# %% [markdown]
# #### 6. 필요없는 column을 del을 사용하여 삭제해주세요.

# %%
[지워야 하는 column]
강간(검거),
강도(검거),
살인(검거),
절도(검거),
폭력(검거),
소계(발생),
소계(검거)

# %%
table = table.drop(
    ['강간(검거)', '강도(검거)', '살인(검거)', '절도(검거)', '폭력(검거)', '소계(발생)', '소계(검거)'], axis=1) #drop axis=1로 열 삭제를 꼭 명시해주기
table

# %% [markdown]
# #### 7. DataFrame의 컬럼명을 rename을 사용하여 변경해주세요.

# %%
[변경해야할 colume]
'강간(발생)':'강간',
'강도(발생)':'강도',
'살인(발생)':'살인',
'절도(발생)':'절도',
'폭력(발생)':'폭력'

# %%
table = table.rename(columns={
    '강간(발생)':'강간',
    '강도(발생)':'강도',
    '살인(발생)':'살인',
    '절도(발생)':'절도',
    '폭력(발생)':'폭력'}) #rename의 columns 옵션은 열 이름을 변경할때, index 옵션은 행 이름을 변경할 때 사용한다.

# %%
table
# Out:
#        강간  강도      관서명  살인    절도    폭력       강건검거율       강도검거율       살인검거율  \
# 구별
# 강남구   449  21   강남서수서서  13  3850  4284   77.728285   85.714286   76.923077
# 강동구   156   6      강동서   4  2366  2712   78.846154  133.333333   75.000000
# 강북구   153  14      강북서   7  1434  2649   82.352941   92.857143  114.285714
# 강서구   262  13      강서서   7  2096  3207   72.900763  100.000000  114.285714
# 관악구   320  12      관악서   9  2706  3298   69.062500  116.666667   88.888889
# 광진구   240  14      광진서   4  3026  2625   91.666667  185.714286  100.000000
# 구로구   281  15      구로서   8  2335  3007   58.362989   73.333333   75.000000
# 금천구   151   6      금천서   3  1567  2054   80.794702  100.000000  133.333333
# 노원구   197   7      노원서  10  2193  2723   61.421320  100.000000  100.000000
# 도봉구   102   9      도봉서   3  1063  1487  103.921569  111.111111  100.000000
# 동대문구  173  13     동대문서   5  1981  2548   84.393064  100.000000  100.000000
# ...

# %%
# 관서명 살짝 지워주기

# %%
table = table.drop(['관서명'], axis = 1) #열을 지웠기 때문에 axis = 1을 추가

# %%
table
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)  살인(검거)  살인(발생)  소계(검거)  소계(발생)  절도(검거)  \
# 구별
# 강남구      349     449      18      21      10      13    5732    8617    1650
# 강동구      123     156       8       6       3       4    3171    5244     789
# 강북구      126     153      13      14       8       7    3113    4257     618
# 강서구      191     262      13      13       8       7    4190    5585    1260
# 관악구      221     320      14      12       8       9    3712    6345     827
# 광진구      220     240      26      14       4       4    3707    5909    1277
# 구로구      164     281      11      15       6       8    3502    5646     889
# 금천구      122     151       6       6       4       3    2796    3781     888
# 노원구      121     197       7       7      10      10    3268    5130     801
# 도봉구      106     102      10       9       3       3    1900    2664     478
# 동대문구     146     173      13      13       5       5    3205    4720     814
# ...

# %% [markdown]
# ##### **구현설명**
# - excel file을 불러오는 함수를 사용하여, 파일을 불러올 때 절대경로를 사용하였습니다.
# - jupyter notebook 으로 코드를 작성하였기 때문에, 출력할 때 pirnt()문을 쓰지 않았습니다.
# - 검거율 계산을 두 가지 방식으로 작성하였습니다. **노가다로 하나씩 계산** 하거나, **for 문을 사용하여 계산** 하는 방식인데, for 문을 쓰는 게 미숙해서 오류 고칠 시간이 부족할 땐 노가다로 자주 했었는데, 연습을 해야 실력도 늘어날거라고 생각해서 for 문으로도 구현해보았습니다.
